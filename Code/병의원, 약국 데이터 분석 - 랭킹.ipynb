# %%
import pandas as pd
import numpy as np
import folium
from tqdm import tqdm

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine = 'openpyxl',nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine = 'openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)
    
# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import numpy as np
import folium
from tqdm import tqdm

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(hospital_ranking)

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(pharmacy_ranking)

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map5.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
#   종별코드명  병원 수
# 0    병원    22
# 1  요양병원    11
# 2  종합병원     3
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
#   종별코드명  약국 수
# 0    약국    12
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install tabulate

# %%
import pandas as pd
import numpy as np
import folium
from tabulate import tabulate
from tqdm import tqdm

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 부족한 병원 종별코드명 추가
missing_hospitals = target_hospitals[~target_hospitals['종별코드명'].isin(hospital_ranking['종별코드명'])]
missing_hospitals_counts = missing_hospitals['종별코드명'].value_counts().reset_index()
missing_hospitals_counts.columns = ['종별코드명', '병원 수']
hospital_ranking = pd.concat([hospital_ranking, missing_hospitals_counts])

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 부족한 약국 종별코드명 추가
missing_pharmacies = target_pharmacies[~target_pharmacies['종별코드명'].isin(pharmacy_ranking['종별코드명'])]
missing_pharmacies_counts = missing_pharmacies['종별코드명'].value_counts().reset_index()
missing_pharmacies_counts.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pd.concat([pharmacy_ranking, missing_pharmacies_counts])

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 부족한 병원 종별 코드명 가져오기
missing_hospital_codes = hospital_ranking[hospital_ranking['병원 수'] <= 1]['종별코드명'].tolist()

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 부족한 병원 종별코드명 출력
print(f"--- {target_region} 지역의 부족한 병원 종별코드명 ---")
print(", ".join(missing_hospital_codes))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 부족한 병원 종별코드명 ---
#
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
# ...

# %%
import pandas as pd
import numpy as np
import folium
from tabulate import tabulate
from tqdm import tqdm

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 병원 전체 데이터에서 병원 종별 코드명 랭킹 계산
overall_hospital_ranking = hospital['종별코드명'].value_counts().reset_index()
overall_hospital_ranking.columns = ['종별코드명', '병원 수']
missing_hospital_codes = overall_hospital_ranking[overall_hospital_ranking['병원 수'] <= 1]

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 부족한 병원 종별 코드명 출력
print(f"--- 부족한 병원 종별 코드명 (1개 이하) ---")
print(tabulate(missing_hospital_codes, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# --- 부족한 병원 종별 코드명 (1개 이하) ---
# +--------------+-----------+
# | 종별코드명   | 병원 수   |
# |--------------+-----------|
# +--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...

# %%
import pandas as pd
import numpy as np
import folium
from tabulate import tabulate
from tqdm import tqdm

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 특정 지역 내에서 부족한 병원 종별코드명 확인
missing_hospital_codes = hospital_ranking[hospital_ranking['병원 수'] <= 1]['종별코드명'].values

if len(missing_hospital_codes) > 0:
    print(f"--- {target_region} 지역에서 부족한 병원 종별코드명 ---")
    print("\n".join(missing_hospital_codes))
else:
    print(f"--- {target_region} 지역에서 부족한 병원 종별코드명이 없습니다. ---")

# 전체 데이터에만 있는 병원 종별코드명 확인
all_hospital_codes = hospital['종별코드명'].unique()
missing_codes = list(set(all_hospital_codes) - set(hospital_ranking['종별코드명']) - set(missing_hospital_codes))

if len(missing_codes) > 0:
    print(f"--- {target_region} 지역에는 부족한 병원 종별코드명이 없지만 전체 데이터에만 있는 병원 종별코드명 ---")
    print("\n".join(missing_codes))
else:
    print(f"--- {target_region} 지역에는 모든 병원 종별코드명이 포함되어 있습니다. ---")

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# --- 전주완산구 지역에서 부족한 병원 종별코드명이 없습니다. ---
# --- 전주완산구 지역에는 부족한 병원 종별코드명이 없지만 전체 데이터에만 있는 병원 종별코드명 ---
# 상급종합
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 전체 데이터에 있는 병원 종별코드명 가져오기
all_hospital_codes = hospital['종별코드명'].unique()

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 부족한 병원 종별코드명 가져오기
missing_hospital_codes = list(set(all_hospital_codes) - set(target_hospitals['종별코드명']))

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역에서 부족한 병원 종별코드명 출력
print(f"--- {target_region} 지역에서 부족한 병원 종별코드명 ---")
if len(missing_hospital_codes) > 0:
    print(", ".join(missing_hospital_codes))
else:
    print("부족한 병원 종별코드명이 없습니다.")

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역에서 부족한 병원 종별코드명 ---
# 상급종합
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 전체 데이터에 있는 병원 종별코드명 가져오기
all_hospital_codes = hospital['종별코드명'].unique()

# 특정 지역 내 종별코드명 가져오기
target_region_codes = target_hospitals['종별코드명'].unique()

# 특정 지역 이외의 종별코드명 가져오기
missing_hospital_codes = list(set(all_hospital_codes) - set(target_region_codes))

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역 이외의 병원 종별코드명 출력
print(f"--- {target_region} 지역의 부족한 병원 종별코드명 ---")
print(", ".join(missing_hospital_codes))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 전주완산구
# --- 전주완산구 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 병원         |        22 |
# |  1 | 요양병원     |        11 |
# |  2 | 종합병원     |         3 |
# +----+--------------+-----------+
# --- 전주완산구 지역 이외의 병원 종별코드명 ---
# 상급종합
# --- 전주완산구 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |        12 |
# +----+--------------+-----------+
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
# ...

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl', nrows=3000)
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl', nrows=3000)
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 가져올 데이터 수
num_records_per_category = 270

# 종별코드명을 기준으로 270개씩 가져오기
hospital_subset = hospital.groupby('종별코드명').head(num_records_per_category)
pharmacy_subset = pharmacy.groupby('종별코드명').head(num_records_per_category)

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 전체 데이터에 있는 병원 종별코드명 가져오기
all_hospital_codes = hospital['종별코드명'].unique()

# 특정 지역 내 종별코드명 가져오기
target_region_codes = target_hospitals['종별코드명'].unique()

# 특정 지역 이외의 종별코드명 가져오기
missing_hospital_codes = list(set(all_hospital_codes) - set(target_region_codes))

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))

# 특정 지역 이외의 병원 종별코드명 출력
print(f"--- {target_region} 지역의 부족한 병원 종별코드명 ---")
print(", ".join(missing_hospital_codes))

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표, 원하는 위치로 변경해주세요

# 병원 위치 표시
for idx, row in target_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = target_hospitals[target_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = target_pharmacies[target_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m

# %%
import pandas as pd
import folium
from tabulate import tabulate

# 병원 정보 데이터셋 불러오기
hospital = pd.read_excel('1.병원정보서비스.xlsx', engine='openpyxl')
hospital = hospital.dropna(subset=['X좌표', 'Y좌표'])

# 약국 정보 데이터셋 불러오기
pharmacy = pd.read_excel('2.약국정보서비스.xlsx', engine='openpyxl')
pharmacy = pharmacy.dropna(subset=['X좌표', 'Y좌표'])

# 특정 지역 설정
target_region = input("특정 지역명을 입력하세요: ")

# 특정 지역의 병원 정보 가져오기
target_hospitals = hospital[hospital['시군구코드명'] == target_region]

# 특정 지역의 약국 정보 가져오기
target_pharmacies = pharmacy[pharmacy['시군구코드명'] == target_region]

# 특정 지역의 병원 종별 코드명 랭킹 계산
hospital_ranking = target_hospitals['종별코드명'].value_counts().reset_index()
hospital_ranking.columns = ['종별코드명', '병원 수']
hospital_ranking = hospital_ranking.sort_values(by='병원 수', ascending=False)

# 특정 지역의 약국 종별 코드명 랭킹 계산
pharmacy_ranking = target_pharmacies['종별코드명'].value_counts().reset_index()
pharmacy_ranking.columns = ['종별코드명', '약국 수']
pharmacy_ranking = pharmacy_ranking.sort_values(by='약국 수', ascending=False)

# 전체 데이터에 있는 병원 종별코드명 가져오기
all_hospital_codes = hospital['종별코드명'].unique()

# 특정 지역 내 종별코드명 가져오기
target_region_codes = target_hospitals['종별코드명'].unique()

# 특정 지역 이외의 종별코드명 가져오기
missing_hospital_codes = list(set(all_hospital_codes) - set(target_region_codes))

# 특정 지역의 병원 종별코드별 개수 출력
print(f"--- {target_region} 지역의 병원 종별코드별 개수 ---")
print(tabulate(hospital_ranking, headers='keys', tablefmt='psql'))
print(" ")

# 특정 지역 이외의 병원 종별코드명 출력
print(f"--- {target_region} 지역의 부족한 병원 종별코드명 ---")
print(", ".join(missing_hospital_codes))
print(" ")

# 특정 지역의 약국 종별코드별 개수 출력
print(f"--- {target_region} 지역의 약국 종별코드별 개수 ---")
print(tabulate(pharmacy_ranking, headers='keys', tablefmt='psql'))
print(" ")

# 종별코드명을 기준으로 일부 데이터 가져오기
subset_hospitals = pd.DataFrame()
#subset_pharmacies = pd.DataFrame()

for code in target_region_codes:
    subset_hospitals = pd.concat([subset_hospitals, target_hospitals[target_hospitals['종별코드명'] == code].head(270)])
    #subset_pharmacies = pd.concat([subset_pharmacies, target_pharmacies[target_pharmacies['종별코드명'] == code].head(24502)])

# 지도 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)  # 서울시 좌표

# 병원 위치 표시
for idx, row in subset_hospitals.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='blue')).add_to(m)

# 약국 위치 표시
for idx, row in target_pharmacies.iterrows():
    folium.Marker([row['Y좌표'], row['X좌표']], tooltip=row['요양기관명'], icon=folium.Icon(color='green')).add_to(m)

# 병원 종별 코드명 랭킹 표시
for idx, row in hospital_ranking.iterrows():
    subset = subset_hospitals[subset_hospitals['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='blue',
                            fill=True,
                            fill_color='blue',
                            fill_opacity=0.6,
                            tooltip=f"종별코드명: {row['종별코드명']}<br>병원 수: {row['병원 수']}"
                            ).add_to(m)

# 약국 종별 코드명 랭킹 표시
for idx, row in pharmacy_ranking.iterrows():
    subset = subset_pharmacies[subset_pharmacies['종별코드명'] == row['종별코드명']]
    for _, loc in subset.iterrows():
        folium.CircleMarker([loc['Y좌표'], loc['X좌표']],
                            radius=10,
                            color='green',
                            fill=True,
                            fill_color='green',
                            fill_opacity=0.6,
                            tooltip=f"종별 코드명: {row['종별코드명']}<br>약국 수: {row['약국 수']}").add_to(m)

# 지도 저장
m.save('map3.html')

# 지도 출력
m
# Out:
# 특정 지역명을 입력하세요: 군산시
# --- 군산시 지역의 병원 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   병원 수 |
# |----+--------------+-----------|
# |  0 | 의원         |       161 |
# |  1 | 치과의원     |        78 |
# |  2 | 한의원       |        71 |
# |  3 | 보건진료소   |        19 |
# |  4 | 보건지소     |        14 |
# |  5 | 요양병원     |         9 |
# |  6 | 병원         |         7 |
# |  7 | 한방병원     |         3 |
# |  8 | 종합병원     |         2 |
# |  9 | 보건소       |         1 |
# +----+--------------+-----------+
#
# --- 군산시 지역의 부족한 병원 종별코드명 ---
# 치과병원, 보건의료원, 조산원, 상급종합, 정신병원
#
# --- 군산시 지역의 약국 종별코드별 개수 ---
# +----+--------------+-----------+
# |    | 종별코드명   |   약국 수 |
# |----+--------------+-----------|
# |  0 | 약국         |       138 |
# +----+--------------+-----------+
# ...
